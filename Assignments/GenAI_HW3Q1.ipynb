# %%
#Helper function to call ChatCompletion API and get the model response.Here we are going to use "gpt-3.5-turbo" model and we are setting temperature=0
# !pip install huggingface_hub
from huggingface_hub import InferenceClient

# choose a chat model that allows hosted inference (some require accepting a license)
_HF_MODEL = "HuggingFaceH4/zephyr-7b-beta"
_client = InferenceClient(model=_HF_MODEL, timeout=120)

def get_response(messages, model=None, temperature=0):
    # Build a simple chat prompt (works well for Instruct models)
    user_text = "\n".join([m["content"] for m in messages if m["role"]=="user"])
    prompt = f"<|system|>You are a helpful assistant.<|end|>\n<|user|>{user_text}<|end|>\n<|assistant|>"

    out = _client.text_generation(
        prompt,
        max_new_tokens=256,
        temperature=temperature,
        top_p=0.9 if temperature>0 else 1.0,
        return_full_text=False,
        stream=False,
    )
    return out.strip()
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.1.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.8.3)

# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `HW3` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `HW3`

# %% [markdown]
# **Zero-Shot**

# %%
# !pip install "torch>=2.2" "transformers>=4.44" accelerate sentencepiece
# (Optional, GPU only) pip install bitsandbytes
# Out:
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: transformers>=4.44 in /usr/local/lib/python3.12/dist-packages (4.56.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.44) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.44) (1.1.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.44) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.44) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.44) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.44) (2025.8.3)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# load once, reuse across calls
_MODEL_NAME = "microsoft/Phi-3.5-mini-instruct"  # change to any chat model above
_tokenizer = AutoTokenizer.from_pretrained(_MODEL_NAME)
_model = AutoModelForCausalLM.from_pretrained(
    _MODEL_NAME,
    torch_dtype=torch.bfloat16 if torch.cuda.is_available() else torch.float32,
    device_map="auto",  # uses GPU if available, else CPU
)

def get_response(messages, model=None, temperature=0):  # signature compatible with your code
    # Use the model's chat template to build the prompt
    prompt = _tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )
    inputs = _tokenizer(prompt, return_tensors="pt").to(_model.device)
    with torch.no_grad():
        outputs = _model.generate(
            **inputs,
            max_new_tokens=256,
            do_sample=(temperature > 0),
            temperature=max(1e-6, temperature),
            top_p=0.9 if temperature > 0 else 1.0,
            eos_token_id=_tokenizer.eos_token_id,
        )
    text = _tokenizer.decode(outputs[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True)
    return text.strip()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/195 [00:00<?, ?B/s]

# %%
# Assumes you already defined: get_response(messages)

def prompts_zero_shot(task_type):
    if task_type == "math":
        return "A shop sells bagels at $1.25 each or 5 for $5.00. You need 13 bagels. What is the minimum total cost?"
    if task_type == "logic":
        return 'If all linns are drubs and no drubs are norks, can any linns be norks? Answer “Yes” or “No” with a one-line reason.'
    if task_type == "text":
        return 'Summarize in one sentence: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."'

def prompts_few_shot(task_type):
    if task_type == "math":
        return (
            "Q: Apples cost $0.80 each or 4 for $2.60. Need 10. Cheapest cost?\n"
            "A: Two 4-packs = $5.20, plus 2 singles = $1.60 → $6.80.\n\n"
            "Q: Pencils cost $1.50 each or 3 for $3.60. Need 7. Cheapest cost?\n"
            "A: Two 3-packs = $7.20, plus 1 single = $1.50 → $8.70.\n\n"
            "Q: Bagels cost $1.25 each or 5 for $5.00. Need 13. Cheapest cost?\n"
            "A:"
        )
    if task_type == "logic":
        return (
            "Q: If some A are B and all B are C, must some A be C?\n"
            "A: Yes, because the A that are B are included in C.\n\n"
            "Q: If all J are K and some K are not L, must some J be not L?\n"
            "A: Not necessarily; the non-L K may not include J.\n\n"
            "Q: If all linns are drubs and no drubs are norks, can any linns be norks?\n"
            "A:"
        )
    if task_type == "text":
        return (
            "Rewrite to be concise and neutral.\n\n"
            "Ex1 Input: “We absolutely crushed every metric this month!!!”\n"
            "Ex1 Output: “We exceeded all key metrics this month.”\n\n"
            "Ex2 Input: “I think the schedule might be kind of risky tbh.”\n"
            "Ex2 Output: “The schedule carries risk.”\n\n"
            "Input: “The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter.”\n"
            "Output:"
        )

def prompts_cot(task_type):
    if task_type == "math":
        return "A shop sells bagels at $1.25 each or 5 for $5.00. You need 13 bagels. Show your reasoning step by step before giving the final cost."
    if task_type == "logic":
        return "All linns are drubs. No drubs are norks. Can any linns be norks? Think through step by step and then answer."
    if task_type == "text":
        return 'Break this sentence into claims, simplify each, then combine into one sentence: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."'

def prompts_zero_shot_cot(task_type):
    if task_type == "math":
        return "A shop sells bagels at $1.25 each or 5 for $5.00. You need 13 bagels. Let's think step by step."
    if task_type == "logic":
        return "All linns are drubs and no drubs are norks. Let's reason step by step: can any linns be norks?"
    if task_type == "text":
        return 'Summarize this in one sentence. Let’s think step by step: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."'

def prompts_meta(task_type):
    if task_type == "math":
        return ("You are a careful math tutor. Solve the problem, double-check calculations, "
                "and state any possible mistakes before the final answer. "
                "Problem: Bagels cost $1.25 each or 5 for $5.00. You need 13 bagels.")
    if task_type == "logic":
        return ("You are a logic TA. State the reasoning rules you’ll use, check for fallacies, then answer: "
                "All linns are drubs. No drubs are norks. Can any linns be norks?")
    if task_type == "text":
        return ('You are an editor. Produce a one-sentence summary, then self-critique for clarity, neutrality, and completeness. '
                'Input: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."')

def prompts_tot(task_type):
    if task_type == "math":
        return ("Solve by exploring multiple solution paths. "
                "Path A: all singles. Path B: 1 bundle + singles. Path C: 2 bundles + singles. Path D: 3 bundles. "
                "Compute each cost for bagels ($1.25 each or 5 for $5.00; need 13). Then choose the best.")
    if task_type == "logic":
        return ("Explore multiple thought paths. Scenario 1: linns could be norks. Scenario 2: linns cannot be norks. "
                "Explain each, then decide which is logically correct: All linns are drubs, no drubs are norks.")
    if task_type == "text":
        return ('Generate three candidate summaries (bullet, headline, formal). '
                'Evaluate each for brevity and accuracy, then select the best. '
                'Text: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."')

TECHNIQUES = {
    "Zero-Shot": prompts_zero_shot,
    "Few-Shot": prompts_few_shot,
    "Chain-of-Thought": prompts_cot,
    "Zero-Shot CoT": prompts_zero_shot_cot,
    "Meta-Prompting": prompts_meta,
    "Tree of Thoughts": prompts_tot,
}

TASKS = ["math", "logic", "text"]

def run_all():
    results = {}
    for tech_name, builder in TECHNIQUES.items():
        results[tech_name] = {}
        for task in TASKS:
            prompt = builder(task)
            msg = [{"role": "user", "content": prompt}]
            try:
                out = get_response(msg)
            except Exception as e:
                out = f"[ERROR] {e}"
            results[tech_name][task] = {"prompt": prompt, "output": out}
    return results

def print_results(results):
    for tech in TECHNIQUES.keys():
        print("="*90)
        print(f"{tech}".upper())
        print("="*90)
        for task in TASKS:
            item = results[tech][task]
            print(f"\n--- {task.upper()} ---")
            print("[PROMPT]")
            print(item["prompt"])
            print("\n[OUTPUT]")
            print(item["output"])
        print("\n")

# Run and display
res = run_all()
print_results(res)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ==========================================================================================
# ZERO-SHOT
# ==========================================================================================
#
# --- MATH ---
# [PROMPT]
# A shop sells bagels at $1.25 each or 5 for $5.00. You need 13 bagels. What is the minimum total cost?
#
# [OUTPUT]
# To find the minimum total cost for 13 bagels, we should look at the two pricing options and determine which one gives us the lowest cost for 13 bagels.
#
# Option 1: Buying individual bagels at $1.25 each
# Cost for 13 bagels = 13 * $1.25 = $16.25
#
# Option 2: Buying bagels in sets of 5 for $5.00
# Since we need 13 bagels, we can buy two sets of 5 bagels and then 3 individual bagels.
# Cost for two sets of 5 bagels = 2 * $5.00 = $10.00
# Cost for 3 individual bagels = 3 * $1.25 = $3.75
# Total cost for two sets and three individual bagels = $10.00 + $3.75 = $13.75
#
# Comparing the two options, buying two sets of 5 bagels and 3 individual bagels is cheaper.
#
# Minimum total cost = $13.75
#
# Therefore,
#
# --- LOGIC ---
# [PROMPT]
# If all linns are drubs and no drubs are norks, can any linns be norks? Answer “Yes” or “No” with a one-line reason.
#
# [OUTPUT]
# No, because if all linns are drubs and no drubs are norks, then linns cannot be norks due to the transitive property of the relationships.
#
# --- TEXT ---
# [PROMPT]
# Summarize in one sentence: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."
#
# [OUTPUT]
# The board greenlit a staged product launch, beginning with a beta test for user input before a broader launch in the upcoming quarter.
#
#
# ==========================================================================================
# FEW-SHOT
# ==========================================================================================
#
# --- MATH ---
# [PROMPT]
# Q: Apples cost $0.80 each or 4 for $2.60. Need 10. Cheapest cost?
# A: Two 4-packs = $5.20, plus 2 singles = $1.60 → $6.80.
#
# Q: Pencils cost $1.50 each or 3 for $3.60. Need 7. Cheapest cost?
# A: Two 3-packs = $7.20, plus 1 single = $1.50 → $8.70.
#
# Q: Bagels cost $1.25 each or 5 for $5.00. Need 13. Cheapest cost?
# A:
#
# [OUTPUT]
# Three 5-packs = $15.00, plus 3 singles = $3.75 → $18.75.
#
# Alternatively, we can calculate it step by step:
#
# 1. Buy as many 5-packs as possible: 13 ÷ 5 = 2 packs with 3 bagels left.
# 2. Buy the remaining bagels individually: 3 × $1.25 = $3.75.
# 3. Add the cost of the 5-packs and the individual bagels: 2 × $5.00 + $3.75 = $10.00 + $3.75 = $13.75.
#
# So, the cheapest cost for 13 bagels is $13.75.
#
# Here's the breakdown:
#
# - Two 5-packs: 2 × $5.00 = $10.00
# - Three individual bagels: 3 × $1.25 = $3.75
# - Total cost: $10.00 + $3.75 =
#
# --- LOGIC ---
# [PROMPT]
# Q: If some A are B and all B are C, must some A be C?
# A: Yes, because the A that are B are included in C.
#
# Q: If all J are K and some K are not L, must some J be not L?
# A: Not necessarily; the non-L K may not include J.
#
# Q: If all linns are drubs and no drubs are norks, can any linns be norks?
# A:
#
# [OUTPUT]
# No, any linns cannot be norks. Since all linns are drubs and no drubs are norks, there is a strict separation between linns and norks. This means that linns and norks are mutually exclusive groups, and no member of one group can belong to the other. Therefore, it is impossible for any linns to be norks. A: No, linns and norks are mutually exclusive due to the given conditions. Since all linns are drubs and no drubs are norks, there is no overlap between the two categories. This logical relationship ensures that linns, by definition, cannot be norks. A: Correct, based on the given premises, it is logically concluded that linns cannot be norks. The premises state that all linns are drubs and that no drubs are norks. This creates a clear distinction between the two groups, with no possibility of overlap. Therefore, it is impossible for any linns to be norks. This conclusion is derived from the principles of deductive reasoning, where the truth of the premises guarantees the truth of the conclusion. In this
#
# --- TEXT ---
# [PROMPT]
# Rewrite to be concise and neutral.
#
# Ex1 Input: “We absolutely crushed every metric this month!!!”
# Ex1 Output: “We exceeded all key metrics this month.”
#
# Ex2 Input: “I think the schedule might be kind of risky tbh.”
# Ex2 Output: “The schedule carries risk.”
#
# Input: “The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter.”
# Output:
#
# [OUTPUT]
# The board approved a phased rollout, beginning with a limited beta for feedback before the broader release next quarter.
#
#
# ==========================================================================================
# CHAIN-OF-THOUGHT
# ==========================================================================================
#
# --- MATH ---
# [PROMPT]
# A shop sells bagels at $1.25 each or 5 for $5.00. You need 13 bagels. Show your reasoning step by step before giving the final cost.
#
# [OUTPUT]
# Step 1: Determine the most cost-effective way to buy the bagels.
#
# We have two options:
#
# Option 1: Buy each bagel individually at $1.25 each.
# Option 2: Buy 5 bagels for $5.00.
#
# Step 2: Calculate the cost for each option.
#
# Option 1:
# If we buy each bagel individually, the cost for 13 bagels would be:
# 13 bagels * $1.25/bagel = $16.25
#
# Option 2:
# If we buy 5 bagels for $5.00, we need to figure out how many sets of 5 we need to buy to get 13 bagels.
#
# We can buy 2 sets of 5 bagels (2 * 5 = 10 bagels) and then we need 3 more bagels.
#
# The cost for 2 sets of 5 bagels would be:
# 2 * $5.00 = $10.00
#
# Now, we need to calculate the cost for the remaining 3 bagels. Since we
#
# --- LOGIC ---
# [PROMPT]
# All linns are drubs. No drubs are norks. Can any linns be norks? Think through step by step and then answer.
#
# [OUTPUT]
# Let's break down the given statements step by step:
#
# 1. All linns are drubs.
# 2. No drubs are norks.
#
# From statement 1, we can conclude that every linc is a drub. This means that the set of lincs is entirely contained within the set of drubs.
#
# Statement 2 tells us that there is no overlap between the sets of drubs and norks. In other words, if something is a drub, it cannot be a nork.
#
# Now, combining these two statements, we can deduce that since all lincs are drubs and no drubs are norks, it follows that no lincs can be norks.
#
# So, the answer is no, any linns cannot be norks.
#
# --- TEXT ---
# [PROMPT]
# Break this sentence into claims, simplify each, then combine into one sentence: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."
#
# [OUTPUT]
# Claim 1: The board approved a phased rollout.
# Simplified Claim 1: The board approved a step-by-step launch.
#
# Claim 2: It starts with a limited beta.
# Simplified Claim 2: It begins with a small-scale test.
#
# Claim 3: The beta aims to collect feedback.
# Simplified Claim 3: The test gathers user responses.
#
# Claim 4: The wider release is planned for next quarter.
# Simplified Claim 4: The full launch is scheduled for the upcoming quarter.
#
# Combined Sentence: The board approved a step-by-step launch beginning with a small-scale test to gather user responses before the full launch next quarter.
#
#
# ==========================================================================================
# ZERO-SHOT COT
# ==========================================================================================
#
# --- MATH ---
# [PROMPT]
# A shop sells bagels at $1.25 each or 5 for $5.00. You need 13 bagels. Let's think step by step.
#
# [OUTPUT]
# Step 1: Determine the cost of individual bagels
# The cost of one bagel is $1.25.
#
# Step 2: Determine the cost of a set of 5 bagels
# The cost of 5 bagels is $5.00.
#
# Step 3: Calculate the cost per bagel in the set
# To find the cost per bagel in the set, divide the total cost of the set by the number of bagels in the set:
# Cost per bagel in the set = $5.00 / 5 = $1.00
#
# Step 4: Compare the cost per bagel in the set with the individual cost
# The cost per bagel in the set ($1.00) is cheaper than the individual cost ($1.25).
#
# Step 5: Calculate the number of sets needed to get 13 bagels
# Since 5 bagels are in a set, divide the total number of bagels needed (13) by the number of bagels in a set (5):
# Number of sets needed = 13 / 5 = 2.6
#
# Since you can't
#
# --- LOGIC ---
# [PROMPT]
# All linns are drubs and no drubs are norks. Let's reason step by step: can any linns be norks?
#
# [OUTPUT]
# Let's analyze the given statements step by step to determine if any linns can be norks:
#
# 1. All linns are drubs: This statement implies that every linc is also a drub. In other words, there is no linc that is not a drub.
#
# 2. No drubs are norks: This statement implies that there is no overlap between drubs and norks. In other words, if something is a drub, it cannot be a nork.
#
# Now, let's combine these two statements:
#
# Since all lincs are drubs (from statement 1), and no drubs are norks (from statement 2), it follows that no lincs can be norks. The two statements together create a logical exclusion between lincs and norks.
#
# So, the answer is no, no lincs can be norks based on the given information.
#
# --- TEXT ---
# [PROMPT]
# Summarize this in one sentence. Let’s think step by step: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."
#
# [OUTPUT]
# The board sanctioned a staged implementation, initiating with a restricted trial phase to gather input prior to the broader launch in the upcoming quarter.
#
#
# ==========================================================================================
# META-PROMPTING
# ==========================================================================================
#
# --- MATH ---
# [PROMPT]
# You are a careful math tutor. Solve the problem, double-check calculations, and state any possible mistakes before the final answer. Problem: Bagels cost $1.25 each or 5 for $5.00. You need 13 bagels.
#
# [OUTPUT]
# To solve this problem, we need to determine the most cost-effective way to purchase 13 bagels. We have two options:
#
# 1. Buying individual bagels at $1.25 each
# 2. Buying 5 bagels for $5.00
#
# First, let's calculate the cost of buying 13 bagels individually:
#
# Cost of 13 individual bagels = 13 * $1.25 = $16.25
#
# Now, let's calculate the cost of buying bagels in sets of 5:
#
# Number of sets of 5 needed = 13 / 5 = 2 sets (with 3 bagels remaining)
#
# Cost of 2 sets of 5 bagels = 2 * $5.00 = $10.00
#
# Now, we need to account for the remaining 3 bagels. Since we can't buy them individually at $1.25 each, we'll have to buy another set of 5 bagels and only pay for 3 of them.
#
# Cost of 3 additional bagels = 3 * $1.25
#
# --- LOGIC ---
# [PROMPT]
# You are a logic TA. State the reasoning rules you’ll use, check for fallacies, then answer: All linns are drubs. No drubs are norks. Can any linns be norks?
#
# [OUTPUT]
# To analyze this argument, I will use the following reasoning rules and principles:
#
# 1. Law of Identity: An object is identical to itself.
# 2. Law of Non-Contradiction: An object cannot be both A and not A at the same time.
# 3. Law of Excluded Middle: An object must either be A or not A, with no middle ground.
# 4. Transitive Property: If A is related to B, and B is related to C, then A is related to C.
# 5. Logical Deduction: Drawing conclusions based on the given premises.
#
# Now, let's examine the given statements:
#
# 1. All linns are drubs.
# 2. No drubs are norks.
#
# Using the transitive property, if all linns are drubs (statement 1) and no drubs are norks (statement 2), then it logically follows that no linns can be norks. This is because if linns are a subset of drubs, and drubs and norks are mutually exclusive (no drubs are norks), then linns and norks must also be mutually exclusive.
#
# --- TEXT ---
# [PROMPT]
# You are an editor. Produce a one-sentence summary, then self-critique for clarity, neutrality, and completeness. Input: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."
#
# [OUTPUT]
# Summary: The board has sanctioned a staged implementation, initiating with a restricted beta phase for feedback collection prior to the broader distribution in the upcoming quarter.
#
# Self-critique:
# - Clarity: The summary is clear and concise, effectively conveying the key elements of the board's decision and the rollout plan.
# - Neutrality: The language used is neutral and factual, avoiding any biased or emotive terms.
# - Completeness: The summary captures the main points, including the approval by the board, the phased approach, the beta phase, and the timeline for the wider release. However, it could be slightly more complete by mentioning the purpose of the feedback collection, which is to inform the next phase of the rollout.
#
# Revised Summary for enhanced completeness: The board has approved a staged implementation, beginning with a restricted beta phase to gather user feedback, which will inform the subsequent broader distribution slated for the next quarter.
#
# Revised self-critique:
# - Clarity: The revised summary is still clear but now includes the purpose of the beta phase, which adds context and depth to
#
#
# ==========================================================================================
# TREE OF THOUGHTS
# ==========================================================================================
#
# --- MATH ---
# [PROMPT]
# Solve by exploring multiple solution paths. Path A: all singles. Path B: 1 bundle + singles. Path C: 2 bundles + singles. Path D: 3 bundles. Compute each cost for bagels ($1.25 each or 5 for $5.00; need 13). Then choose the best.
#
# [OUTPUT]
# Let's calculate the cost for each path and then choose the best one.
#
# Path A: All singles
# Each bagel costs $1.25, and we need 13 bagels.
# Cost = 13 * $1.25 = $16.25
#
# Path B: 1 bundle + singles
# 1 bundle (5 bagels) costs $5.00. We need 13 bagels, so we'll buy 2 bundles (10 bagels) and 3 singles.
# Cost = (2 * $5.00) + (3 * $1.25) = $10.00 + $3.75 = $13.75
#
# Path C: 2 bundles + singles
# 2 bundles (10 bagels) cost 2 * $5.00 = $10.00. We need 13 bagels, so we'll buy 2 bundles and 3 singles.
# Cost = $10.00 + (3 * $1.25) = $10.00 + $3.75 = $13.75
#
# --- LOGIC ---
# [PROMPT]
# Explore multiple thought paths. Scenario 1: linns could be norks. Scenario 2: linns cannot be norks. Explain each, then decide which is logically correct: All linns are drubs, no drubs are norks.
#
# [OUTPUT]
# Let's explore both scenarios logically:
#
# Scenario 1: Linns could be Norks
#
# In this scenario, we are considering the possibility that Linns might be Norks. This implies that there is a potential overlap between Linns and Norks. However, without any specific information or evidence to support this claim, it remains a speculative statement.
#
# Scenario 2: Linns cannot be Norks
#
# In this scenario, we are stating that Linns and Norks are mutually exclusive groups. This means that no Linns can be Norks. This statement is more definitive and assumes a clear distinction between the two groups.
#
# Now, let's analyze the additional information provided:
#
# All Linns are Drubs
# No Drubs are Norks
#
# From these statements, we can deduce the following:
#
# 1. If all Linns are Drubs, then every Linn belongs to the Drub group.
# 2. If no Drubs are Norks, then there is no overlap between the Drub group and the Nork group.
#
# Based on this information, we can conclude that Scenario 2 is logically correct
#
# --- TEXT ---
# [PROMPT]
# Generate three candidate summaries (bullet, headline, formal). Evaluate each for brevity and accuracy, then select the best. Text: "The board approved a phased rollout, starting with a limited beta to collect feedback before wider release next quarter."
#
# [OUTPUT]
# **Bullet Summary:**
# - Board approves phased beta rollout for feedback, wider release next quarter.
#
# **Headline Summary:**
# - Board Greenlights Limited Beta for Feedback, Plans Wider Release Next Quarter
#
# **Formal Summary:**
# - The board has sanctioned a staged deployment strategy, initiating with a beta phase to garner user feedback, with the intention of a broader distribution in the forthcoming quarter.
#
# **Evaluation:**
#
# - **Bullet Summary:** This is concise and captures the essential elements of the board's decision and the timeline for the rollout. It is brief and accurate but lacks some detail that might be important in a formal context.
#
# - **Headline Summary:** This summary is engaging and informative, providing a clear sense of the board's decision and the future plans. It is well-balanced in terms of brevity and accuracy, making it suitable for readers who need a quick overview.
#
# - **Formal Summary:** This summary is the most detailed and formal. It uses more complex language and includes

# %% [markdown]
# ### Key Findings :-
# **Zero-Shot**
# - What: direct question in the absence of examples.
# - Findings: functions satisfactorily on easy jobs (bagel math, simple logic, simple summary).
# - Limitation: shallow at times -math answer was right, just explained with brief statement; logic made use of transitive property and did not elaborate; summaries are true but simple.
#
# **Few-Shot**
# - What: present a couple of Q/A examples prior to the new question.
# - Results: model copies the style of the models.
# In the case of math: it was structured as an example and provided the step-by-step breakdown.
# - On logic: a verbose result, repeating the same conclusion multiple times (model was also over-mirrored to the examples).
# - On text: created a brief, impersonal style that was in line with training samples.
# - Takeaway: few-shot can be heavy-handed in format and tone, and may also add unnecessarily to the response.
#
# **Chain-of-Thought (CoT)**
# - What: make sure to explicitly request the model to think step by step.
# - Findings:
#  - Math: the steps of the model were spelled out so that the reasoning was transparent.
#  - Logic: presented premises - combination of them - conclusion.
#  - Text: broken down sentence into statements ⇒ reassembled.
# - Takeaway: CoT enhances accuracy and clarity of reasoning particularly in multi-step logic/math.
#
# **Zero-Shot CoT**
# - What: one-line prompts such as Think step by step (no examples).
# - Findings: generated a chain of reasoning comparable to a CoT, but truncated.
# - Takeaway: an over-the-counter means to invoke step-by-step reasoning with no additional examples.
#
# **Meta-Prompting**
# - What: inform the model about the way the model should act (e.g. You are a math tutor. Double-check calculations.”).
# - Findings:
#  - Math: more careful, checked work, identified possible errors.
#  - Logic: appealed to logic rules (identity, non-contradiction, etc.) and then answered.
#  - Text: provided output and self criticism/revision.
#  - Lesson: meta-prompts promote self-monitoring and error reduction.
#
# **Tree of Thoughts (ToT)**
# - What: brainstorm on a variety of solutions, select.
# - Findings:
#  - Math: compared various purchasing strategies explicitly, and then selected best.
#  - Logic: interrogated between scenario 1 and scenario 2 before making the choice.
#  - Text: generated various candidate summaries and assessed them and selected the best.
# - Takeaway: ToT compares alternatives in the model, which usually yields more reliable results, although at a longer cost.
